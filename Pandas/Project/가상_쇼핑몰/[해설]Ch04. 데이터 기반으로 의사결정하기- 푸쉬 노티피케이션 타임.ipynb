# %% [markdown]
# ### 학습목표
# 1. 푸쉬 노티피케이션 타임 의사 결정 하기

# %%
import numpy as np
import pandas as pd
# seaborn
import seaborn as sns
COLORS = sns.color_palette()

# %matplotlib inline

# %%
def plot_bar(df, xlabel, ylabel, title, figsize=(20, 10), color=COLORS[-1], rotation=45):
    plot = df.plot(kind='bar', color=color, figsize=figsize)
    plot.set_xlabel(xlabel, fontsize=10)
    plot.set_ylabel(ylabel, fontsize=10)
    plot.set_title(title, fontsize=12)
    plot.set_xticklabels(labels=df.index, rotation=rotation)

# %%
dtypes = {
    'UnitPrice': np.float32,
    'CustomerID': np.int32,
    'Quantity': np.int32
}
retail = pd.read_csv('../source_data/OnlineRetailClean.csv', dtype=dtypes)
retail['InvoiceDate'] = pd.to_datetime(retail['InvoiceDate'], infer_datetime_format=True)
retail.head()
# Out:
# /var/folders/h8/dk4pn1l11_5f5z7pscs8gr0r0000gn/T/ipykernel_33210/3157118038.py:7: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   retail['InvoiceDate'] = pd.to_datetime(retail['InvoiceDate'], infer_datetime_format=True)
#    Unnamed: 0  InvoiceNo StockCode                          Description  \
# 0           0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1           1     536365     71053                  WHITE METAL LANTERN
# 2           2     536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3           3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4           4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
#
#    Quantity         InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %% [markdown]
# #### 쿠폰 발송을 할때, push를 언제 보내는게 좋을까?
#  - 고객에게 쿠폰 발송을 한다고 기획하고, 회의를 한다고 가정해보겠습니다.
#   - A: 쿠폰을 언제보내는게 좋을까요?
#   - B: 아침에 출퇴근 시간에 보내는게 좋을까요?
#   - C: 점심 먹고 졸린데 그때 보내보죠?
#   - D: 흠 자기전에 스마트폰 많이 하던데 그때는 어떨까요?
#   - A: 그러면 평균 시간을 내볼까요?
#   - K: 아 **데이터**를 확인해보는게 맞지 않을까요? 언제 고객이 주로 주문을 하는지?
#
#
#  - 위에서 처럼 실제로 회의를 하다보면 의사결정이 본인/주변의 경험에 의해서 이뤄지는 것을 많이 볼 수 있습니다.
#  - 주문이 이뤄지는 시간을 고려하지 않고 막무가내로 보낸다면 아무 의미가 없고, 추후 같은 이벤트 발생시에도 판단 근거가 없게 됨
#  - 현상태에서는 가장 많이 주문이 일어나는 시점에서 하는 것이 가장 직관적인 판단
#    - 1. 데이터로 파악
#    - 2. 가설 제시
#    - 3. 가설 검증
#    - 4. 1-3 반복
#  - 시간(hour, minute)과 주로 관련되기 때문에 역시 InvoiceDate가 중요한 feature

# %%
order_by_hour = retail.set_index('InvoiceDate').groupby(lambda date: date.hour).count()['CustomerID']
order_by_hour
# Out:
# InvoiceDate
# 6         1
# 7       379
# 8      8690
# 9     21944
# 10    37997
# 11    49084
# 12    72065
# 13    64026
# 14    54118
# 15    45369
# 16    24089
# 17    13071
# 18     2928
# 19     3321
# 20      802
# Name: CustomerID, dtype: int64

# %%
plot_bar(order_by_hour, 'hour', '# orders', 'Order by hour')

# %%
def half_an_hour(date):
    minute = ':00'
    if date.minute > 30:
        minute = ':30'
    hour = str(date.hour)
    if date.hour < 10:
        hour = '0' + hour
    
    return hour + minute

# %%
order_by_hour_half = retail.set_index('InvoiceDate').groupby(half_an_hour).count()['CustomerID']
order_by_hour_half
# Out:
# InvoiceDate
# 06:00        1
# 07:30      379
# 08:00     3145
# 08:30     5545
# 09:00     9364
# 09:30    12580
# 10:00    16950
# 10:30    21047
# 11:00    18925
# 11:30    30159
# 12:00    37174
# 12:30    34891
# 13:00    31131
# 13:30    32895
# 14:00    26958
# 14:30    27160
# 15:00    24227
# 15:30    21142
# 16:00    14316
# 16:30     9773
# 17:00     8889
# 17:30     4182
# 18:00     1715
# 18:30     1213
# 19:00     1534
# 19:30     1787
# 20:00      802
# Name: CustomerID, dtype: int64

# %%
order_by_hour_half / order_by_hour_half.sum()
# Out:
# InvoiceDate
# 06:00    0.000003
# 07:30    0.000953
# 08:00    0.007904
# 08:30    0.013936
# 09:00    0.023534
# 09:30    0.031617
# 10:00    0.042600
# 10:30    0.052897
# 11:00    0.047564
# 11:30    0.075798
# 12:00    0.093429
# 12:30    0.087691
# 13:00    0.078241
# 13:30    0.082675
# 14:00    0.067753
# 14:30    0.068261
# 15:00    0.060890
# 15:30    0.053136
# 16:00    0.035980
# 16:30    0.024562
# 17:00    0.022341
# 17:30    0.010511
# 18:00    0.004310
# 18:30    0.003049
# 19:00    0.003855
# 19:30    0.004491
# 20:00    0.002016
# Name: CustomerID, dtype: float64

# %%
plot_bar(order_by_hour_half, 'half an hour', '# orders', 'order by half an hour')

# %% [markdown]
# #### 개인화된 push notification
#  - 아마존을 필두로, 개인화(personalization)하여 맞춤으로 사용자마다 최적의 솔루션을 찾는것이 트렌드가 됨
#  - 사용자별로 소비의 패턴이 다를 수 있기 때문에, 가장 많이 구매한 시간대를 찾아서 해당 시간대에 쿠폰을 발송!

# %% [markdown]
# #### 사용자별 각 시간별 주문 량 계산하기

# %%
order_count_by_hour = retail.set_index('InvoiceDate').groupby(['CustomerID', lambda date: date.hour]).count()['StockCode']
order_count_by_hour
# Out:
# CustomerID  InvoiceDate
# 12346       10              1
# 12347       8              22
#             10             24
#             12             47
#             13             18
#                            ..
# 18283       15              1
#             16             56
#             19             87
# 18287       9               3
#             10             67
# Name: StockCode, Length: 11205, dtype: int64

# %% [markdown]
# #### 사용자별 최대 주문 시간 계산하기
#  - 가장 많은 주문량을 보인 시간을 계산

# %%
idx = order_count_by_hour.groupby('CustomerID').idxmax()
idx
# Out:
# CustomerID
# 12346    (12346, 10)
# 12347    (12347, 14)
# 12348    (12348, 19)
# 12349     (12349, 9)
# 12350    (12350, 16)
#             ...
# 18280     (18280, 9)
# 18281    (18281, 10)
# 18282    (18282, 13)
# 18283    (18283, 14)
# 18287    (18287, 10)
# Name: StockCode, Length: 4338, dtype: object

# %% [markdown]
# #### 해당 시간 indexing

# %%
result = order_count_by_hour.loc[idx]
result
# Out:
# CustomerID  InvoiceDate
# 12346       10               1
# 12347       14              60
# 12348       19              17
# 12349       9               73
# 12350       16              17
#                           ...
# 18280       9               10
# 18281       10               7
# 18282       13               7
# 18283       14             201
# 18287       10              67
# Name: StockCode, Length: 4338, dtype: int64

# %%
result.reset_index().groupby('CustomerID').groups
# Out:
# {12346: [0], 12347: [1], 12348: [2], 12349: [3], 12350: [4], 12352: [5], 12353: [6], 12354: [7], 12355: [8], 12356: [9], 12357: [10], 12358: [11], 12359: [12], 12360: [13], 12361: [14], 12362: [15], 12363: [16], 12364: [17], 12365: [18], 12367: [19], 12370: [20], 12371: [21], 12372: [22], 12373: [23], 12374: [24], 12375: [25], 12377: [26], 12378: [27], 12379: [28], 12380: [29], 12381: [30], 12383: [31], 12384: [32], 12386: [33], 12388: [34], 12390: [35], 12391: [36], 12393: [37], 12394: [38], 12395: [39], 12397: [40], 12398: [41], 12399: [42], 12401: [43], 12402: [44], 12403: [45], 12405: [46], 12406: [47], 12407: [48], 12408: [49], 12409: [50], 12410: [51], 12412: [52], 12413: [53], 12414: [54], 12415: [55], 12417: [56], 12418: [57], 12420: [58], 12421: [59], 12422: [60], 12423: [61], 12424: [62], 12425: [63], 12426: [64], 12427: [65], 12428: [66], 12429: [67], 12430: [68], 12431: [69], 12432: [70], 12433: [71], 12434: [72], 12435: [73], 12436: [74], 12437: [75], 12438: [76], 12441:
# ...

# %%
order_count_by_hour.reset_index()
# Out:
#        CustomerID  InvoiceDate  StockCode
# 0           12346           10          1
# 1           12347            8         22
# 2           12347           10         24
# 3           12347           12         47
# 4           12347           13         18
# ...           ...          ...        ...
# 11200       18283           15          1
# 11201       18283           16         56
# 11202       18283           19         87
# 11203       18287            9          3
# 11204       18287           10         67
#
# [11205 rows x 3 columns]

# %%
order_count_by_hour.values
# Out:
# array([ 1, 22, 24, ..., 87,  3, 67])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 'order_count_by_hour' 데이터에서 'CustomerID', 'InvoiceDate', 'StockCode'만 있는 상태
# 새로운 열 'Product/Month' 생성 (CustomerID, InvoiceDate, StockCode 결합)
rev_by_dow_reset = order_count_by_hour.reset_index()
order_count_by_hour['Product/Month'] = rev_by_dow_reset['CustomerID'].astype(str) + ' / ' + rev_by_dow_reset['InvoiceDate'].astype(str) + ' / ' + rev_by_dow_reset['StockCode'].astype(str)

# 'Product/Month'별 주문 수를 계산
product_month_counts = order_count_by_hour.groupby('Product/Month').size().reset_index(name='Order Count')

# Seaborn을 사용하여 바 차트 그리기 (주문 수를 y축으로 사용)
plt.figure(figsize=(12, 6))
sns.barplot(x='Product/Month', y='Order Count', data=product_month_counts, palette='Blues_d')

# 그래프 제목과 레이블 설정
plt.xlabel('Product / Month', fontsize=11)
plt.ylabel('Order Count', fontsize=11)
plt.title('Order Count by Product and Month', fontsize=13)

# x축 레이블 회전
plt.xticks(rotation=45)

# 그래프 출력
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 13
#      10 plt.figure(figsize=(12, 6))
#      12 # Seaborn을 사용하여 바 차트 그리기 (주문 수를 y축으로 사용)
# ---> 13 sns.barplot(x=order_count_by_hour['Product/Month'], y=order_count_by_hour.groupby('Product/Month').size(), palette='Blues_d')
#      15 # 그래프 제목과 레이블 설정
#      16 plt.xlabel('Product / Month', fontsize=11)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/series.py:2247, in Series.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    2244     raise TypeError("as_index=False only valid with DataFrame")
#    2245 axis = self._get_axis_number(axis)
# -> 2247 return SeriesGroupBy(
#    2248     obj=self,
#    2249     keys=by,
#    2250     axis=axis,
#    2251     level=level,
#    2252     as_index=as_index,
#    2253     sort=sort,
#    2254     group_keys=group_keys,
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:100, in pandas._libs.index.Int32Engine._check_type()
#
# KeyError: 'Product/Month'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 order_count_by_hour['Product/Month']
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/series.py:1121, in Series.__getitem__(self, key)
# ...
